# %% [markdown]
# # Visualizing Earnings Based On College Majors

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
recent_grads = recent_grads.dropna()

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   16723.406977   22646.674419
# std     49.983181  1679.240095   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.750000  2403.750000    4549.750000    2177.500000    1778.250000
# 50%     87.500000  3608.500000   15104.000000    5434.000000    8386.500000
# 75%    130.250000  5503.250000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size      Employed      Full_time      Part_time  \
# count  172.000000   172.000000     172.00000     172.000000     172.000000
# mean     0.522223   357.941860   31355.80814   26165.767442    8877.232558
# ...

# %% [markdown]
# ## **Pandas, Scatter Plot**

# %%
ax = recent_grads.plot(x="Sample_size",y="Median",kind="scatter")
ax.set_title("Sample Size vs Median")

# %%
ax = recent_grads.plot(x="Sample_size",y="Unemployment_rate",kind="scatter")
ax.set_title("Sample Size vs Unemployment Rate")

# %%
ax = recent_grads.plot(x="Full_time",y="Median",kind="scatter")
ax.set_title("Full Time vs Median")

# %%
ax = recent_grads.plot(x="ShareWomen",y="Unemployment_rate",kind="scatter")
ax.set_title("Share Women vs Unemployment Rate")

# %%
ax = recent_grads.plot(x="Men",y="Median",kind="scatter")
ax.set_title("Men vs Median")

# %%
ax = recent_grads.plot(x="Women",y="Median",kind="scatter")
ax.set_title("Women vs Median")

# %% [markdown]
# ## Question : Do students in more popular majors make more money?

# %%
ax = recent_grads.plot(x="Total",y="Median",kind="scatter")
ax.set_title("Total vs Median")

# %% [markdown]
# From the above plt we can say that the answer to the question is **NO**. Reason is The most popular major with 393735 students makes only between 20000 and 40000.

# %% [markdown]
# ## Question : Do students that majored in subjects that were majority female make more money?

# %% [markdown]
# From **Women vs. Median** plot we can say that maximum females made money between 20000 to 40000. So the answer is no.

# %% [markdown]
# ## Question : Is there any link between the number of full-time employees and median salary?

# %% [markdown]
# No.

# %% [markdown]
# ## ** Pandas, Histograms**

# %%
recent_grads["Sample_size"].plot(kind = "hist",bins = 20,grid=True)

# %%
recent_grads["Median"].plot(kind = "hist",rot = 30, grid = True)

# %%
recent_grads["Employed"].plot(kind = "hist",rot = 30,grid = True)

# %%
recent_grads["Full_time"].plot(kind = "hist",rot = 30,grid = True)

# %%
recent_grads["ShareWomen"].plot(kind = "hist",rot = 30,grid = True)

# %%
recent_grads["Unemployment_rate"].plot(kind = "hist",rot = 30,grid = True)

# %%
recent_grads["Men"].plot(kind = "hist",rot = 30,grid = True)

# %%
recent_grads["Women"].plot(kind = "hist",rot = 30,grid = True)

# %% [markdown]
# ## Question : What percent of majors are predominantly male? Predominantly female?

# %%
total_men = recent_grads["Men"].sum()
total_men
# Out:
# 2876426.0

# %%
total_women = recent_grads["Women"].sum()
total_women
# Out:
# 3895228.0

# %%
total_students = total_men + total_women
total_students
# Out:
# 6771654.0

# %%
men_percentage = (100*total_men)/total_students
men_percentage
# Out:
# 42.47745085617192

# %%
women_percentage = (100*total_women)/total_students
women_percentage
# Out:
# 57.52254914382808

# %% [markdown]
# So we can see that 57.52% are females and 42.48% are men.

# %% [markdown]
# ## Question : What's the most common median salary range?

# %% [markdown]
# 20000-40000

# %% [markdown]
# ## Pandas, Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[["Sample_size","Median"]],figsize=(10,10),grid = True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9e18093518>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]],figsize=(10,10),grid = True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9e17eda278>,
# ...
#       dtype=object)

# %% [markdown]
# ## Pandas, Bar Plots

# %%
recent_grads[:10]["ShareWomen"].plot(kind='bar')

# %%
recent_grads[162:173]["ShareWomen"].plot(kind = "bar")

# %% [markdown]
# So the percentage of women is much higher in last 10 rows of the dataframe.

# %%
recent_grads[:10]["Unemployment_rate"].plot(kind='bar')

# %%
recent_grads[162:173]["Unemployment_rate"].plot(kind='bar')

# %% [markdown]
# So we see that there is an overall growth in unemployment rate.
